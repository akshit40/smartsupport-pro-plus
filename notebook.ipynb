# %% [markdown]
# # SmartSupport PRO+ Demo Notebook
#
# This notebook runs the demo of SmartSupport PRO+ locally with mock tools. No API keys required.

# %%
# !pip install -q -r requirements.txt

# %%
import sys
sys.path.append('src')
print('Paths OK. Running demo...')

# %%
from agent_orchestrator import handle_ticket
from tools.ticket_api import fetch_pending_tickets
tickets = fetch_pending_tickets()
for t in tickets:
    print('\n--- Running ticket:', t['id'], '---')
    handle_ticket(t)
